# %%
import pandas as pd

# %%
df = pd.read_csv('cleaned_global_water_consumption.csv')
df
# Out:
#        Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 0    Argentina  2000                                      481.490000
# 1    Argentina  2001                                      455.063000
# 2    Argentina  2002                                      482.749231
# 3    Argentina  2003                                      452.660000
# 4    Argentina  2004                                      634.566000
# ..         ...   ...                                             ...
# 495        USA  2020                                      418.097000
# 496        USA  2021                                      572.094000
# 497        USA  2022                                      440.978000
# 498        USA  2023                                      566.865000
# 499        USA  2024                                      249.485000
#
#      Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
totalWC = df[['Country','Total Water Consumption (Billion Cubic Meters)']].groupby('Country').sum()
totalWC
# Out:
#               Total Water Consumption (Billion Cubic Meters)
# Country
# Argentina                                       13284.860759
# Australia                                       12505.778389
# Brazil                                          13263.287436
# Canada                                          12352.694690
# China                                           13133.596733
# France                                          12596.115707
# Germany                                         12668.588927
# India                                           12581.662785
# Indonesia                                       12151.267472
# Italy                                           12449.631513
# Japan                                           12585.683217
# Mexico                                          12058.054255
# Russia                                          12385.526576
# Saudi Arabia                                    12966.078679
# ...

# %%
sns.barplot(data=totalWC,x = 'Country',y='Total Water Consumption (Billion Cubic Meters)', gap= 0.5)
# Out:
# <Axes: xlabel='Country', ylabel='Total Water Consumption (Billion Cubic Meters)'>

# %%
covid = pd.read_csv('Data\\covid_19_clean_complete.csv')
covid
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
covid.isna().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %%
# 50 questions on the above dataset for practicing data visualization:

# ### General Questions:
# 1. What is the distribution of total water consumption across all countries?
# 2. How does per capita water use vary across different years?
# 3. What are the top 10 countries with the highest total water consumption?
# 4. Create a bar chart to compare agricultural, industrial, and household water use for a specific year.
# 5. Show the trend of groundwater depletion rates over time.
# 6. Compare industrial and household water use with a scatter plot.
# 7. Visualize rainfall impact across different countries.
# 8. Create a histogram to show the distribution of per capita water use.
# 9. Show a heatmap of correlations between different numerical variables.
# 10. Compare the water consumption of two different countries using a line plot.

# ### Time-Series Analysis:
# 11. Plot a time-series graph showing the total water consumption trends.
# 12. Compare the per capita water use of a country over the years.
# 13. Create a rolling average plot for total water consumption.
# 14. Show the trend of agricultural water use percentage over time.
# 15. Compare the rainfall impact over the years for multiple countries.

# ### Country-Based Analysis:
# 16. Which country had the highest groundwater depletion rate in a given year?
# 17. Compare water consumption patterns between two countries.
# 18. Create a pie chart showing the proportion of agricultural, industrial, and household water use in a country.
# 19. Plot a grouped bar chart comparing water consumption of the top 5 countries.
# 20. Show a boxplot comparing per capita water use across countries.

# ### Comparisons:
# 21. Compare per capita water use for high rainfall vs. low rainfall countries.
# 22. Create a scatter plot of groundwater depletion rate vs. total water consumption.
# 23. How does industrial water use correlate with per capita water use?
# 24. Compare total water consumption of developed vs. developing countries (categorize manually).
# 25. Visualize agricultural vs. industrial water use with a stacked bar chart.

# ### Relationship Between Variables:
# 26. How does groundwater depletion relate to total water consumption?
# 27. Does higher rainfall always mean lower water consumption?
# 28. Show the relationship between population size (if available) and water consumption.
# 29. Create a jointplot of groundwater depletion rate and per capita water use.
# 30. Create a pairplot for the key variables in the dataset.

# ### Data Distribution:
# 31. Show a KDE plot for the distribution of total water consumption.
# 32. Create a violin plot to visualize per capita water use distribution.
# 33. Find and visualize outliers in groundwater depletion rate.
# 34. Plot a swarmplot for different water usage types.
# 35. Create a density plot for rainfall impact.

# ### Advanced Visualizations:
# 36. Create a choropleth map of total water consumption by country.
# 37. Use a treemap to show water usage categories across countries.
# 38. Create an animated visualization of water consumption trends over years.
# 39. Generate a radar chart to compare different water usage metrics of a country.
# 40. Use a violin plot to compare water usage categories across multiple countries.

# ### Multi-Variable Comparisons:
# 41. Show a stacked area plot of total water consumption over time.
# 42. Create a facet grid comparing industrial and household water use.
# 43. Compare the top 5 and bottom 5 countries in terms of per capita water use.
# 44. Create a heatmap of water consumption trends over time.
# 45. Show an annotated line plot highlighting important changes in water consumption.

# ### Miscellaneous:
# 46. Find missing values in the dataset and visualize them.
# 47. Show how rainfall affects agricultural water use.
# 48. Compare the growth rate of water consumption across countries.
# 49. Create a bar plot showing the change in water use from the first year to the last year for each country.
# 50. Use Seaborn’s regplot to fit a regression line for groundwater depletion vs. total water consumption.

# These questions will help you practice various visualization techniques in Python using Matplotlib and Seaborn. Let me know if you want to generate sample code for any of them! 🚀
